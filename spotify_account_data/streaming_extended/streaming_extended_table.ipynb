# %%
import pandas as pd
from pathlib import Path
import os

FOLDER = Path('/Users/qaulanmaruf/Desktop/alans_spotify_2025/spotify_account_data/streaming_extended')
audio_stream_extended = []

for file in FOLDER.glob('Streaming_History_Audio*'):
    audio_stream_extended.append(pd.read_json(file))

audio_stream_extended = pd.concat(audio_stream_extended, ignore_index=True)

# %%
from IPython.display import display

display(audio_stream_extended.head(10))
# Out:
#                      ts platform  ms_played conn_country       ip_addr  \
# 0  2024-06-23T08:43:16Z      ios     188000           ID  182.2.137.77
# 1  2024-06-23T08:44:37Z      ios      79546           ID  182.2.137.77
# 2  2024-06-23T08:44:38Z      ios       1020           ID  182.2.137.77
# 3  2024-06-23T08:44:40Z      ios       2090           ID  182.2.137.77
# 4  2024-06-23T08:44:43Z      ios       2500           ID  182.2.137.77
# 5  2024-06-23T08:44:43Z      ios        540           ID  182.2.137.77
# 6  2024-06-23T08:44:55Z      ios      11430           ID  182.2.137.77
# 7  2024-06-23T08:44:57Z      ios       1860           ID  182.2.137.77
# 8  2024-06-23T08:45:00Z      ios       3300           ID  182.2.137.77
# 9  2024-06-23T08:45:01Z      ios       1210           ID  182.2.137.77
#
#                     master_metadata_track_name  \
# 0                                 Terang Bulan
# 1  Make Me an Island (Original 1969 Recording)
# ...

# %%
audio_stream_extended = pd.read_json(FOLDER / "Streaming_History_Video_2022-2026.json")

# %%
display(audio_stream_extended.head(10))
# Out:
#                      ts platform  ms_played conn_country         ip_addr  \
# 0  2022-11-30T15:35:31Z      ios          0           NL  144.178.95.154
# 1  2022-11-30T15:35:31Z      ios       8429           NL  144.178.95.154
# 2  2022-11-30T15:35:39Z      ios       8572           NL  144.178.95.154
# 3  2022-11-30T15:35:39Z      ios          0           NL  144.178.95.154
# 4  2022-11-30T15:35:39Z      ios          0           NL  144.178.95.154
# 5  2022-11-30T15:35:42Z      ios          0           NL  144.178.95.154
# 6  2022-11-30T15:35:42Z      ios          0           NL  144.178.95.154
# 7  2022-11-30T15:35:42Z      ios       2200           NL  144.178.95.154
# 8  2023-07-21T03:23:42Z      ios       4364           ID     182.3.43.98
# 9  2023-07-21T03:23:46Z      ios       3823           ID     182.3.43.98
#
#    master_metadata_track_name master_metadata_album_artist_name  \
# 0      Terluka Menginginkanmu                       Mark Natama
# ...
